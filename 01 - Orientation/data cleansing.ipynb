# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(7,7))
df[df > 0.5] = np.nan
df
# Out:
#           0         1         2         3         4         5         6
# 0 -0.937504 -1.142092 -0.320397 -0.579366 -0.434762 -0.387961 -0.618855
# 1  0.183497       NaN -0.018657 -0.074053       NaN -0.411697       NaN
# 2  0.384903 -0.033874       NaN -0.876052 -2.757783       NaN       NaN
# 3       NaN       NaN       NaN       NaN -0.414804 -1.044258 -0.044691
# 4  0.126636 -0.456429       NaN -0.490384 -1.854403       NaN  0.163530
# 5 -1.325047  0.160209  0.379715       NaN -0.110461  0.301027       NaN
# 6 -0.825236       NaN  0.426784 -1.264030       NaN -0.240721       NaN

# %%
print(df.isnull())
# Out:
#        0      1      2      3      4      5      6
# 0  False  False  False  False  False  False  False
# 1  False   True  False  False   True  False   True
# 2  False  False   True  False  False   True   True
# 3   True   True   True   True  False  False  False
# 4  False  False   True  False  False   True  False
# 5  False  False  False   True  False  False   True
# 6  False   True  False  False   True  False   True

# %%
print(df.isnull().sum())
# Out:
# 0    1
# 1    3
# 2    3
# 3    2
# 4    2
# 5    2
# 6    4
# dtype: int64

# %%
print(df.isnull().sum().sum())
# Out:
# 17

# %%
df.index = ['a','b','c','d','e','f','g']
df
# Out:
#           0         1         2         3         4         5         6
# a -0.937504 -1.142092 -0.320397 -0.579366 -0.434762 -0.387961 -0.618855
# b  0.183497       NaN -0.018657 -0.074053       NaN -0.411697       NaN
# c  0.384903 -0.033874       NaN -0.876052 -2.757783       NaN       NaN
# d       NaN       NaN       NaN       NaN -0.414804 -1.044258 -0.044691
# e  0.126636 -0.456429       NaN -0.490384 -1.854403       NaN  0.163530
# f -1.325047  0.160209  0.379715       NaN -0.110461  0.301027       NaN
# g -0.825236       NaN  0.426784 -1.264030       NaN -0.240721       NaN

# %%
df.dropna()
# Out:
#           0         1         2         3         4         5         6
# a -0.937504 -1.142092 -0.320397 -0.579366 -0.434762 -0.387961 -0.618855

# %%
df.fillna(0, inplace = True)
print(df)
# Out:
#           0         1         2         3         4         5         6
# a -0.937504 -1.142092 -0.320397 -0.579366 -0.434762 -0.387961 -0.618855
# b  0.183497  0.000000 -0.018657 -0.074053  0.000000 -0.411697  0.000000
# c  0.384903 -0.033874  0.000000 -0.876052 -2.757783  0.000000  0.000000
# d  0.000000  0.000000  0.000000  0.000000 -0.414804 -1.044258 -0.044691
# e  0.126636 -0.456429  0.000000 -0.490384 -1.854403  0.000000  0.163530
# f -1.325047  0.160209  0.379715  0.000000 -0.110461  0.301027  0.000000
# g -0.825236  0.000000  0.426784 -1.264030  0.000000 -0.240721  0.000000

# %%
df = pd.DataFrame(np.random.randn(7,6))
df[df > 0.9] = np.nan
df
# Out:
#           0         1         2         3         4         5
# 0 -0.932749  0.197933 -1.438203 -0.514555 -1.373676  0.895890
# 1       NaN  0.440307 -1.351158  0.794034  0.211759       NaN
# 2 -0.098773 -0.990028 -0.234462 -0.088959       NaN       NaN
# 3 -0.529013 -0.483242 -0.485223       NaN -0.989745 -0.568994
# 4 -0.995920  0.751413 -1.225476 -1.119937  0.732246  0.565590
# 5 -1.430308 -0.235227 -0.853198 -0.950198 -0.152982 -0.393590
# 6 -0.535324 -0.833143  0.228057       NaN  0.717548 -1.323857

# %%
df[0].fillna(df[0].mean(), inplace = True)
df
# Out:
#           0         1         2         3         4         5
# 0 -0.932749  0.197933 -1.438203 -0.514555 -1.373676  0.895890
# 1 -0.753681  0.440307 -1.351158  0.794034  0.211759       NaN
# 2 -0.098773 -0.990028 -0.234462 -0.088959       NaN       NaN
# 3 -0.529013 -0.483242 -0.485223       NaN -0.989745 -0.568994
# 4 -0.995920  0.751413 -1.225476 -1.119937  0.732246  0.565590
# 5 -1.430308 -0.235227 -0.853198 -0.950198 -0.152982 -0.393590
# 6 -0.535324 -0.833143  0.228057       NaN  0.717548 -1.323857

# %%
for column_name in df:
    df[column_name].fillna(df[column_name].mean(), inplace = True)
df
# Out:
#           0         1         2         3         4         5
# 0 -0.932749  0.197933 -1.438203 -0.514555 -1.373676  0.895890
# 1 -0.753681  0.440307 -1.351158  0.794034  0.211759 -0.164992
# 2 -0.098773 -0.990028 -0.234462 -0.088959 -0.142475 -0.164992
# 3 -0.529013 -0.483242 -0.485223 -0.375923 -0.989745 -0.568994
# 4 -0.995920  0.751413 -1.225476 -1.119937  0.732246  0.565590
# 5 -1.430308 -0.235227 -0.853198 -0.950198 -0.152982 -0.393590
# 6 -0.535324 -0.833143  0.228057 -0.375923  0.717548 -1.323857

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
df = pd.read_csv('Sberbank Housing Market.csv')

# %%
df.shape
# Out:
# (30471, 292)

# %%
df.dtypes
# Out:
# id                      int64
# timestamp              object
# full_sq                 int64
# life_sq               float64
# floor                 float64
#                        ...
# mosque_count_5000       int64
# leisure_count_5000      int64
# sport_count_5000        int64
# market_count_5000       int64
# price_doc               int64
# Length: 292, dtype: object

# %%
from pandas.plotting import scatter_matrix

# %%
df_fewer_columns = df.iloc[:, 77:80:1]

# %%
scatter_matrix(df_fewer_columns, figsize = (12, 12));

# %%
import missingno as msno

# %%
df_some_columns = df.iloc[:, 30:60:1]

# %%
msno.matrix(df_some_columns)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df_some_columns)
# Out:
# <AxesSubplot:>

# %%
limitPer = len(df_some_columns) * .80
df_some_columns.dropna(axis='columns', thresh = limitPer, inplace = True)

# %%
msno.bar(df_some_columns)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot:>
